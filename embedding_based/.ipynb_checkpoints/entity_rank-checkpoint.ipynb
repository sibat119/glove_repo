# %%
import numpy as np
from scipy import spatial
import matplotlib.pyplot as plt
from collections import namedtuple
from operator import attrgetter

rankTuple = namedtuple('word', 'word distance')

# %%
embeddings_dict = {}
words = {}
i = 0
glove_data = '../glove.6B.200d.txt'
f = open(glove_data, encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    words[i] = word
    vector = np.asarray(values[1:], "float32")
    embeddings_dict[word] = vector
    i += 1

print(len(words))
print(len(embeddings_dict))
# Out:
# 400000
# 400000

# %%
def find_closest_embeddings_euclidean(vector_map, embedding):
    return sorted(vector_map.keys(), key=lambda word: spatial.distance.euclidean(vector_map[word], embedding))

def find_closest_with_distance_euclidean(vector_map, embedding):
    rank_val_attr_map = []
    for key, val in vector_map.items():
        distance = spatial.distance.euclidean(val, embedding)
        rtuple = rankTuple(key, distance)
        rank_val_attr_map.append(rtuple)
    return sorted(rank_val_attr_map, key=attrgetter('distance'))

def find_closest_with_distance_cosine(vector_map, embedding):
    rank_val_attr_map = []
    for key, val in vector_map.items():
        distance = spatial.distance.cosine(val, embedding)
        rtuple = rankTuple(key, distance)
        rank_val_attr_map.append(rtuple)
    #print(rank_val_attr_map)
    return sorted(rank_val_attr_map, key=attrgetter('distance'))

def find_closest_embeddings_cosine(vector_map, embedding):
    return sorted(vector_map.keys(), key=lambda word: spatial.distance.cosine(vector_map[word], embedding))

def find_euclidean_distance(vec1, vec2):
    return spatial.distance.euclidean(vec1, vec2)

def find_cosine_distance(vec1, vec2):
    return spatial.distance.cosine(vec1, vec2)

def get_avg_sum_embedding(line, dictionary):
    sum_of_vector = np.full((200, ), 0)
    word_vec = line.split()
    for word in word_vec:
        embedding = dictionary.get(word, np.full((200, ), 0))
        sum_of_vector = np.add(embedding, sum_of_vector)
    sum_of_vector = np.divide(sum_of_vector, len(word_vec)) 
    return sum_of_vector

# %%
attr_map = 'Trane-Demos/three_datasets/flight-delay/FlightDelay.mapping'
attr_description_map = {}
attr_vector_map = {}
f = open(attr_map, encoding="utf8")
for line in f:
    values = line.split('|')
    word = values[0]
    attr_description_map[word] = values[1].split('\n')[0]

for key, val in attr_description_map.items():
    attr_vector_map[key] = get_avg_sum_embedding(val, embeddings_dict)

# %%
human_query_dict = {}
query_file_loc = 'human_query/query.txt'
f = open(query_file_loc, encoding="utf8")
writer = open('output.txt', 'w')
sum_of_human_query_vector = np.full((200, ), 0)
for line in f:
    writer.write(line + "\n")
    query = line.split("|")[0]
    sum_of_human_query_vector = get_avg_sum_embedding(query, embeddings_dict)
    human_query_dict[query] = sum_of_human_query_vector
    rank_euclidian = find_closest_with_distance_euclidean(attr_vector_map, sum_of_human_query_vector)
    rank_cosine = find_closest_with_distance_cosine(attr_vector_map, sum_of_human_query_vector)
    print(rank_cosine)
    writer.write("Euclidian rank -> " + str(rank_euclidian) + "\n\n")
    writer.write("Cosine rank -> " + str(rank_cosine) + "\n\n")
# Out:
# [word(word='DAY_OF_WEEK', distance=0.1634186437585502), word(word='CANCELLATION_REASON', distance=0.17725899360957176), word(word='DATE', distance=0.1929378904975052), word(word='FLIGHT_NUMBER', distance=0.1965578855029435), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.19857605943182666), word(word='ARRIVAL_DELAY', distance=0.20222937545051534), word(word='SCHEDULED_TIME', distance=0.2084113620414626), word(word='CANCELLED', distance=0.23063716223529274), word(word='AIR_SYSTEM_DELAY', distance=0.23464804856118715), word(word='DEPARTURE_DELAY', distance=0.23642055483283408), word(word='AIRLINE_DELAY', distance=0.2535990489360471), word(word='SECURITY_DELAY', distance=0.2569453361486985), word(word='TAIL_NUMBER', distance=0.25805887632623314), word(word='ELAPSED_TIME', distance=0.25966135006960245), word(word='LATE_AIRCRAFT_DELAY', distance=0.2635855408465375), word(word='WEATHER_DELAY', distance=0.28168508642469414), word(word='ORIGIN_AIRPORT', distance=0.3663548002942737), word(word='DESTINATION_AIRPORT', distance=0.37196973971787706), word(word='AIRLINE', distance=0.4101054208481181)]
# [word(word='DATE', distance=0.11982710105335159), word(word='DAY_OF_WEEK', distance=0.1280938681705437), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.13277718790065884), word(word='CANCELLATION_REASON', distance=0.1402482135223514), word(word='ARRIVAL_DELAY', distance=0.1412688005225914), word(word='DEPARTURE_DELAY', distance=0.14852843288353879), word(word='SCHEDULED_TIME', distance=0.15430545200239787), word(word='FLIGHT_NUMBER', distance=0.15964349538807399), word(word='CANCELLED', distance=0.16502088691230277), word(word='AIR_SYSTEM_DELAY', distance=0.18711359508713998), word(word='AIRLINE_DELAY', distance=0.19667042771986198), word(word='SECURITY_DELAY', distance=0.1966960116881059), word(word='ELAPSED_TIME', distance=0.19958772739843955), word(word='LATE_AIRCRAFT_DELAY', distance=0.20288136694656844), word(word='TAIL_NUMBER', distance=0.22235859623454546), word(word='WEATHER_DELAY', distance=0.2333300459155453), word(word='ORIGIN_AIRPORT', distance=0.37223950586140664), word(word='DESTINATION_AIRPORT', distance=0.38169833181859536), word(word='AIRLINE', distance=0.4015290618849007)]
# [word(word='DAY_OF_WEEK', distance=0.12379378639969119), word(word='DATE', distance=0.12957686986925365), word(word='ARRIVAL_DELAY', distance=0.13398553948250125), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.14166054476975665), word(word='CANCELLATION_REASON', distance=0.14614616060990626), word(word='SCHEDULED_TIME', distance=0.15376024340311856), word(word='FLIGHT_NUMBER', distance=0.15831494010954705), word(word='DEPARTURE_DELAY', distance=0.16590895439492026), word(word='CANCELLED', distance=0.1686868665452823), word(word='AIR_SYSTEM_DELAY', distance=0.18985400316674306), word(word='ELAPSED_TIME', distance=0.1992835435850392), word(word='SECURITY_DELAY', distance=0.20063593457636442), word(word='AIRLINE_DELAY', distance=0.20448982251863557), word(word='LATE_AIRCRAFT_DELAY', distance=0.20520018597633405), word(word='TAIL_NUMBER', distance=0.2212361122667682), word(word='WEATHER_DELAY', distance=0.23320696214144343), word(word='ORIGIN_AIRPORT', distance=0.35601555996845524), word(word='DESTINATION_AIRPORT', distance=0.3708740185193612), word(word='AIRLINE', distance=0.4116282034324136)]
# [word(word='AIR_SYSTEM_DELAY', distance=0.101640626316295), word(word='DAY_OF_WEEK', distance=0.11029334294705473), word(word='SECURITY_DELAY', distance=0.1445651382687252), word(word='FLIGHT_NUMBER', distance=0.14717682136159393), word(word='AIRLINE_DELAY', distance=0.14840462168627466), word(word='CANCELLATION_REASON', distance=0.15023487290222814), word(word='LATE_AIRCRAFT_DELAY', distance=0.15100939686511827), word(word='DATE', distance=0.15646787677631802), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.16030085383559467), word(word='ARRIVAL_DELAY', distance=0.16108935007733594), word(word='CANCELLED', distance=0.16994706766236667), word(word='WEATHER_DELAY', distance=0.17966990586973497), word(word='DEPARTURE_DELAY', distance=0.1827495265406881), word(word='SCHEDULED_TIME', distance=0.18573030326141093), word(word='TAIL_NUMBER', distance=0.1898678397963227), word(word='ELAPSED_TIME', distance=0.21964649047481444), word(word='AIRLINE', distance=0.3818864601618164), word(word='ORIGIN_AIRPORT', distance=0.39008648226862463), word(word='DESTINATION_AIRPORT', distance=0.42072408258879124)]
# [word(word='DAY_OF_WEEK', distance=0.10020762205733658), word(word='SECURITY_DELAY', distance=0.12215030437993502), word(word='AIR_SYSTEM_DELAY', distance=0.1405151760802713), word(word='ARRIVAL_DELAY', distance=0.1486260818206362), word(word='LATE_AIRCRAFT_DELAY', distance=0.14955270109700536), word(word='FLIGHT_NUMBER', distance=0.15525603747766625), word(word='CANCELLATION_REASON', distance=0.1585015688777467), word(word='DATE', distance=0.15896080514580013), word(word='AIRLINE_DELAY', distance=0.16000636968835857), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.1653162376608457), word(word='DEPARTURE_DELAY', distance=0.169979482956493), word(word='SCHEDULED_TIME', distance=0.17411330413567705), word(word='CANCELLED', distance=0.18009551273267133), word(word='WEATHER_DELAY', distance=0.18979671369749085), word(word='TAIL_NUMBER', distance=0.20452399211539007), word(word='ELAPSED_TIME', distance=0.21290851300823066), word(word='ORIGIN_AIRPORT', distance=0.39287530821342775), word(word='AIRLINE', distance=0.4060456888443834), word(word='DESTINATION_AIRPORT', distance=0.4193347790320662)]
# [word(word='DAY_OF_WEEK', distance=0.10979510343531351), word(word='FLIGHT_NUMBER', distance=0.1409729235565026), word(word='AIR_SYSTEM_DELAY', distance=0.14576264824776863), word(word='CANCELLATION_REASON', distance=0.14578353791931986), word(word='AIRLINE_DELAY', distance=0.14590467322233103), word(word='ARRIVAL_DELAY', distance=0.15880341547123122), word(word='DATE', distance=0.16001749220798478), word(word='SECURITY_DELAY', distance=0.16331092402815905), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.16373214859889695), word(word='LATE_AIRCRAFT_DELAY', distance=0.16507214286929717), word(word='DEPARTURE_DELAY', distance=0.17624351209837208), word(word='TAIL_NUMBER', distance=0.18089760045979342), word(word='SCHEDULED_TIME', distance=0.1828872507502286), word(word='CANCELLED', distance=0.1829332214989725), word(word='WEATHER_DELAY', distance=0.20406433971622706), word(word='ELAPSED_TIME', distance=0.21744677164180082), word(word='AIRLINE', distance=0.3208172667616821), word(word='ORIGIN_AIRPORT', distance=0.3975193217487346), word(word='DESTINATION_AIRPORT', distance=0.41787171688859037)]
# [word(word='DAY_OF_WEEK', distance=0.10204758572696182), word(word='FLIGHT_NUMBER', distance=0.13778214876119443), word(word='AIR_SYSTEM_DELAY', distance=0.14535148275677368), word(word='CANCELLATION_REASON', distance=0.14658900735855418), word(word='LATE_AIRCRAFT_DELAY', distance=0.14669268046070594), word(word='ARRIVAL_DELAY', distance=0.1509927933241848), word(word='DATE', distance=0.15208660416355868), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.15722975396458305), word(word='TAIL_NUMBER', distance=0.1623115780320472), word(word='SECURITY_DELAY', distance=0.16267469663609913), word(word='AIRLINE_DELAY', distance=0.16800733929071343), word(word='SCHEDULED_TIME', distance=0.17206023589942276), word(word='DEPARTURE_DELAY', distance=0.17768392223392693), word(word='CANCELLED', distance=0.181533703615529), word(word='WEATHER_DELAY', distance=0.19753964880195563), word(word='ELAPSED_TIME', distance=0.2106878704569023), word(word='ORIGIN_AIRPORT', distance=0.39178549173565214), word(word='AIRLINE', distance=0.39620300084246507), word(word='DESTINATION_AIRPORT', distance=0.4234168363895302)]
# [word(word='DAY_OF_WEEK', distance=0.09820893338974312), word(word='AIR_SYSTEM_DELAY', distance=0.14321592989400533), word(word='ARRIVAL_DELAY', distance=0.14415500420162708), word(word='CANCELLATION_REASON', distance=0.14660373466465726), word(word='FLIGHT_NUMBER', distance=0.14789365809289245), word(word='LATE_AIRCRAFT_DELAY', distance=0.15317032097694216), word(word='SECURITY_DELAY', distance=0.15589116899374533), word(word='DATE', distance=0.16294909685878123), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.16415780796418267), word(word='WEATHER_DELAY', distance=0.16850720705302458), word(word='SCHEDULED_TIME', distance=0.16935422187388183), word(word='AIRLINE_DELAY', distance=0.1700050837984597), word(word='DEPARTURE_DELAY', distance=0.17219906975678734), word(word='CANCELLED', distance=0.18468587132541603), word(word='TAIL_NUMBER', distance=0.19330807415738438), word(word='ELAPSED_TIME', distance=0.20232147386915234), word(word='ORIGIN_AIRPORT', distance=0.4071022298033694), word(word='AIRLINE', distance=0.4183423230300195), word(word='DESTINATION_AIRPORT', distance=0.4321604463135411)]
# [word(word='DAY_OF_WEEK', distance=0.1634186437585502), word(word='CANCELLATION_REASON', distance=0.17725899360957176), word(word='DATE', distance=0.1929378904975052), word(word='FLIGHT_NUMBER', distance=0.1965578855029435), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.19857605943182666), word(word='ARRIVAL_DELAY', distance=0.20222937545051534), word(word='SCHEDULED_TIME', distance=0.2084113620414626), word(word='CANCELLED', distance=0.23063716223529274), word(word='AIR_SYSTEM_DELAY', distance=0.23464804856118715), word(word='DEPARTURE_DELAY', distance=0.23642055483283408), word(word='AIRLINE_DELAY', distance=0.2535990489360471), word(word='SECURITY_DELAY', distance=0.2569453361486985), word(word='TAIL_NUMBER', distance=0.25805887632623314), word(word='ELAPSED_TIME', distance=0.25966135006960245), word(word='LATE_AIRCRAFT_DELAY', distance=0.2635855408465375), word(word='WEATHER_DELAY', distance=0.28168508642469414), word(word='ORIGIN_AIRPORT', distance=0.3663548002942737), word(word='DESTINATION_AIRPORT', distance=0.37196973971787706), word(word='AIRLINE', distance=0.4101054208481181)]
# [word(word='DAY_OF_WEEK', distance=0.1511316052202477), word(word='FLIGHT_NUMBER', distance=0.20123069537059424), word(word='SCHEDULED_TIME', distance=0.2025256231456466), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.20770684457006028), word(word='CANCELLATION_REASON', distance=0.21927744775065738), word(word='ARRIVAL_DELAY', distance=0.22687839835029178), word(word='ELAPSED_TIME', distance=0.22822774704379478), word(word='DATE', distance=0.2322206924870679), word(word='DEPARTURE_DELAY', distance=0.25042394290443404), word(word='TAIL_NUMBER', distance=0.25465765886799374), word(word='AIR_SYSTEM_DELAY', distance=0.27176297783304193), word(word='LATE_AIRCRAFT_DELAY', distance=0.2731592274018889), word(word='SECURITY_DELAY', distance=0.27640704624745216), word(word='CANCELLED', distance=0.2836297437913178), word(word='AIRLINE_DELAY', distance=0.29314683874024716), word(word='WEATHER_DELAY', distance=0.3033859475043402), word(word='AIRLINE', distance=0.46896963308452244), word(word='ORIGIN_AIRPORT', distance=0.5111460620560175), word(word='DESTINATION_AIRPORT', distance=0.5262849312675616)]
# [word(word='DAY_OF_WEEK', distance=0.16622066948409575), word(word='CANCELLATION_REASON', distance=0.1755618368142431), word(word='SCHEDULED_TIME', distance=0.18953618393821525), word(word='ARRIVAL_DELAY', distance=0.1962267427539338), word(word='DATE', distance=0.20615418069456826), word(word='FLIGHT_NUMBER', distance=0.2161759688612157), word(word='DEPARTURE_DELAY', distance=0.21749993458138783), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.22647139868585986), word(word='SECURITY_DELAY', distance=0.23419249857363678), word(word='AIR_SYSTEM_DELAY', distance=0.23482036022875197), word(word='CANCELLED', distance=0.23577771045611406), word(word='AIRLINE_DELAY', distance=0.2386843247305085), word(word='LATE_AIRCRAFT_DELAY', distance=0.24517494824640962), word(word='WEATHER_DELAY', distance=0.26767482550773036), word(word='ELAPSED_TIME', distance=0.2678464448084811), word(word='TAIL_NUMBER', distance=0.27182721170634605), word(word='AIRLINE', distance=0.42611105127514215), word(word='DESTINATION_AIRPORT', distance=0.44423790752234094), word(word='ORIGIN_AIRPORT', distance=0.455149952785766)]
# [word(word='DAY_OF_WEEK', distance=0.1035000098395844), word(word='CANCELLATION_REASON', distance=0.16639204172694078), word(word='FLIGHT_NUMBER', distance=0.17544239777588944), word(word='DATE', distance=0.17852549183028643), word(word='SCHEDULED_TIME', distance=0.17896283857848316), word(word='ARRIVAL_DELAY', distance=0.18354383220639037), word(word='AIR_SYSTEM_DELAY', distance=0.1992856594476945), word(word='CANCELLED', distance=0.20055081930401975), word(word='SECURITY_DELAY', distance=0.20163476814494796), word(word='DEPARTURE_DELAY', distance=0.2035343679388183), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.2049184794427572), word(word='LATE_AIRCRAFT_DELAY', distance=0.2133409723960925), word(word='ELAPSED_TIME', distance=0.22181709781530634), word(word='TAIL_NUMBER', distance=0.22444505940199233), word(word='AIRLINE_DELAY', distance=0.22549850903085622), word(word='WEATHER_DELAY', distance=0.24536181988553363), word(word='AIRLINE', distance=0.42947980714891965), word(word='ORIGIN_AIRPORT', distance=0.432354421434507), word(word='DESTINATION_AIRPORT', distance=0.4581887514821651)]
# [word(word='DAY_OF_WEEK', distance=0.08681994471803411), word(word='FLIGHT_NUMBER', distance=0.1446029182898695), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.1515589475848197), word(word='ARRIVAL_DELAY', distance=0.1550341340353527), word(word='AIR_SYSTEM_DELAY', distance=0.16142162779121882), word(word='CANCELLATION_REASON', distance=0.16177350731501916), word(word='DATE', distance=0.16400942631058224), word(word='DEPARTURE_DELAY', distance=0.1694572066655442), word(word='SCHEDULED_TIME', distance=0.17820676275833192), word(word='TAIL_NUMBER', distance=0.18977874809668438), word(word='CANCELLED', distance=0.19486088422053793), word(word='ELAPSED_TIME', distance=0.19628073289809145), word(word='SECURITY_DELAY', distance=0.19682830176354804), word(word='LATE_AIRCRAFT_DELAY', distance=0.20458731777478478), word(word='AIRLINE_DELAY', distance=0.2194168116135029), word(word='WEATHER_DELAY', distance=0.2385078808601343), word(word='AIRLINE', distance=0.4241068754220674), word(word='ORIGIN_AIRPORT', distance=0.4401697034861156), word(word='DESTINATION_AIRPORT', distance=0.4675350951068159)]
# [word(word='DAY_OF_WEEK', distance=0.10040272457488286), word(word='ARRIVAL_DELAY', distance=0.14548742162270956), word(word='AIR_SYSTEM_DELAY', distance=0.15483942238431647), word(word='FLIGHT_NUMBER', distance=0.15792872384375212), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.16357729377182384), word(word='LATE_AIRCRAFT_DELAY', distance=0.16413179119757093), word(word='CANCELLATION_REASON', distance=0.1668616766904284), word(word='SECURITY_DELAY', distance=0.1669316113578212), word(word='WEATHER_DELAY', distance=0.1707009311856218), word(word='DATE', distance=0.17520981625770204), word(word='DEPARTURE_DELAY', distance=0.1785853278274575), word(word='SCHEDULED_TIME', distance=0.18349679296491672), word(word='ELAPSED_TIME', distance=0.18970993164247374), word(word='AIRLINE_DELAY', distance=0.1903989632911598), word(word='TAIL_NUMBER', distance=0.20351499886296776), word(word='CANCELLED', distance=0.20746343770252607), word(word='ORIGIN_AIRPORT', distance=0.4352759531926642), word(word='AIRLINE', distance=0.4452732664308541), word(word='DESTINATION_AIRPORT', distance=0.4674759796862482)]
# [word(word='DAY_OF_WEEK', distance=0.11915034630423138), word(word='FLIGHT_NUMBER', distance=0.12073301960604832), word(word='TAIL_NUMBER', distance=0.142900357332169), word(word='SCHEDULED_TIME', distance=0.14983132156386036), word(word='ELAPSED_TIME', distance=0.1665470459780748), word(word='DATE', distance=0.16733238327173627), word(word='CANCELLATION_REASON', distance=0.17214736446318601), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18544630074700097), word(word='CANCELLED', distance=0.1908989339046009), word(word='ARRIVAL_DELAY', distance=0.21639462668288867), word(word='AIR_SYSTEM_DELAY', distance=0.22500280664266292), word(word='DEPARTURE_DELAY', distance=0.2446659002481456), word(word='SECURITY_DELAY', distance=0.2549591765058089), word(word='AIRLINE_DELAY', distance=0.26724852264917176), word(word='LATE_AIRCRAFT_DELAY', distance=0.26811044809193985), word(word='WEATHER_DELAY', distance=0.2893474236603193), word(word='ORIGIN_AIRPORT', distance=0.4032204142450574), word(word='AIRLINE', distance=0.42715271539287525), word(word='DESTINATION_AIRPORT', distance=0.43702798810836296)]
# [word(word='DAY_OF_WEEK', distance=0.10200500850042293), word(word='SCHEDULED_TIME', distance=0.11043857171027305), word(word='DATE', distance=0.14400954976691127), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.15053354246746398), word(word='ELAPSED_TIME', distance=0.1721781539273799), word(word='FLIGHT_NUMBER', distance=0.17893378156488493), word(word='ARRIVAL_DELAY', distance=0.1802482806207174), word(word='CANCELLATION_REASON', distance=0.182122136687765), word(word='CANCELLED', distance=0.20212354880156314), word(word='DEPARTURE_DELAY', distance=0.2032429969204299), word(word='TAIL_NUMBER', distance=0.24454749334893588), word(word='AIR_SYSTEM_DELAY', distance=0.24695533550600646), word(word='LATE_AIRCRAFT_DELAY', distance=0.24819865599485702), word(word='SECURITY_DELAY', distance=0.25716863885472685), word(word='AIRLINE_DELAY', distance=0.2815218488397393), word(word='WEATHER_DELAY', distance=0.2917384219544158), word(word='ORIGIN_AIRPORT', distance=0.41805039519783027), word(word='DESTINATION_AIRPORT', distance=0.4380944545421477), word(word='AIRLINE', distance=0.46224068038372645)]
# [word(word='FLIGHT_NUMBER', distance=0.09734662334091071), word(word='DAY_OF_WEEK', distance=0.10968052878383538), word(word='TAIL_NUMBER', distance=0.1179010590160775), word(word='DATE', distance=0.13895335234984985), word(word='CANCELLATION_REASON', distance=0.15520946818409442), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.1619259278353028), word(word='CANCELLED', distance=0.1651473231370132), word(word='SCHEDULED_TIME', distance=0.1698888423579693), word(word='ARRIVAL_DELAY', distance=0.17056785633197802), word(word='ELAPSED_TIME', distance=0.18403005099419134), word(word='AIR_SYSTEM_DELAY', distance=0.1932940181876477), word(word='DEPARTURE_DELAY', distance=0.20291816275564156), word(word='SECURITY_DELAY', distance=0.2192608625329765), word(word='AIRLINE_DELAY', distance=0.23116833115963487), word(word='LATE_AIRCRAFT_DELAY', distance=0.23398921422117647), word(word='WEATHER_DELAY', distance=0.26035214494379344), word(word='ORIGIN_AIRPORT', distance=0.3718835256712648), word(word='DESTINATION_AIRPORT', distance=0.40401272635537977), word(word='AIRLINE', distance=0.4157599273167957)]
# [word(word='FLIGHT_NUMBER', distance=0.11732598380475678), word(word='DAY_OF_WEEK', distance=0.11978698350656147), word(word='DATE', distance=0.14797603607669463), word(word='CANCELLATION_REASON', distance=0.14824468220408304), word(word='CANCELLED', distance=0.1532787447732752), word(word='TAIL_NUMBER', distance=0.16857184886390397), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.1697512275732188), word(word='ARRIVAL_DELAY', distance=0.189579508430608), word(word='SCHEDULED_TIME', distance=0.19048088108432093), word(word='AIR_SYSTEM_DELAY', distance=0.1977376098383714), word(word='ELAPSED_TIME', distance=0.20106016194805765), word(word='AIRLINE_DELAY', distance=0.21557428836537962), word(word='DEPARTURE_DELAY', distance=0.21954654666854445), word(word='SECURITY_DELAY', distance=0.22628603726159535), word(word='LATE_AIRCRAFT_DELAY', distance=0.24987864915879865), word(word='WEATHER_DELAY', distance=0.27899837361538105), word(word='ORIGIN_AIRPORT', distance=0.2851707966717042), word(word='DESTINATION_AIRPORT', distance=0.3484087059168435), word(word='AIRLINE', distance=0.35515340553244534)]
# [word(word='DAY_OF_WEEK', distance=0.127334623019022), word(word='FLIGHT_NUMBER', distance=0.13205333779606676), word(word='CANCELLATION_REASON', distance=0.14728473871139247), word(word='DATE', distance=0.15438842219328397), word(word='CANCELLED', distance=0.16213927682665652), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.16682260878464117), word(word='TAIL_NUMBER', distance=0.18779865564668285), word(word='ARRIVAL_DELAY', distance=0.18889211443044163), word(word='SCHEDULED_TIME', distance=0.19003474797306608), word(word='ELAPSED_TIME', distance=0.19801638289428802), word(word='AIR_SYSTEM_DELAY', distance=0.20084108626557418), word(word='AIRLINE_DELAY', distance=0.21297430339217738), word(word='DEPARTURE_DELAY', distance=0.22204638310524571), word(word='SECURITY_DELAY', distance=0.23495103604986534), word(word='LATE_AIRCRAFT_DELAY', distance=0.2560673393924148), word(word='WEATHER_DELAY', distance=0.2739504746969482), word(word='ORIGIN_AIRPORT', distance=0.2806992274210861), word(word='DESTINATION_AIRPORT', distance=0.3402357965566497), word(word='AIRLINE', distance=0.34513583593160757)]
# [word(word='DAY_OF_WEEK', distance=0.08079765636498104), word(word='DATE', distance=0.12532319382497203), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.13449667357683226), word(word='FLIGHT_NUMBER', distance=0.13550487557267887), word(word='CANCELLATION_REASON', distance=0.14339291062230042), word(word='ARRIVAL_DELAY', distance=0.1446144328121597), word(word='DEPARTURE_DELAY', distance=0.14950553459487048), word(word='SCHEDULED_TIME', distance=0.1539498508794297), word(word='CANCELLED', distance=0.1552788963809908), word(word='ELAPSED_TIME', distance=0.15940119570027267), word(word='TAIL_NUMBER', distance=0.19472358519715494), word(word='AIR_SYSTEM_DELAY', distance=0.20190065276951386), word(word='SECURITY_DELAY', distance=0.2103168476044941), word(word='LATE_AIRCRAFT_DELAY', distance=0.22028729473799658), word(word='AIRLINE_DELAY', distance=0.22858098292589135), word(word='WEATHER_DELAY', distance=0.24700266142869398), word(word='ORIGIN_AIRPORT', distance=0.4261817198411382), word(word='AIRLINE', distance=0.43481285132777325), word(word='DESTINATION_AIRPORT', distance=0.453855761981802)]
# [word(word='DAY_OF_WEEK', distance=0.13934518312038668), word(word='DEPARTURE_DELAY', distance=0.15090756335025834), word(word='ARRIVAL_DELAY', distance=0.15135587137266815), word(word='CANCELLATION_REASON', distance=0.1529515327919002), word(word='DATE', distance=0.1724631330335893), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.17312647942558268), word(word='AIRLINE_DELAY', distance=0.1890245710851235), word(word='SCHEDULED_TIME', distance=0.2022038292848488), word(word='FLIGHT_NUMBER', distance=0.20255264640303328), word(word='AIR_SYSTEM_DELAY', distance=0.21042173824727828), word(word='CANCELLED', distance=0.2108114105796418), word(word='ELAPSED_TIME', distance=0.21881190639145898), word(word='SECURITY_DELAY', distance=0.22660023583547473), word(word='LATE_AIRCRAFT_DELAY', distance=0.23014033616207097), word(word='WEATHER_DELAY', distance=0.2550411043241603), word(word='TAIL_NUMBER', distance=0.261345011892816), word(word='AIRLINE', distance=0.33099173704910223), word(word='ORIGIN_AIRPORT', distance=0.4620676521343148), word(word='DESTINATION_AIRPORT', distance=0.4653399593329013)]
# [word(word='CANCELLATION_REASON', distance=0.1753321541700087), word(word='AIRLINE_DELAY', distance=0.17746607934077674), word(word='DAY_OF_WEEK', distance=0.19222864776691073), word(word='FLIGHT_NUMBER', distance=0.2164377749043317), word(word='ARRIVAL_DELAY', distance=0.22420233772530007), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.2251890546607489), word(word='AIR_SYSTEM_DELAY', distance=0.22660552651127897), word(word='DATE', distance=0.23397585405676335), word(word='CANCELLED', distance=0.23590792921044612), word(word='DEPARTURE_DELAY', distance=0.23717753069051717), word(word='AIRLINE', distance=0.23971836397854152), word(word='SCHEDULED_TIME', distance=0.258845462977246), word(word='TAIL_NUMBER', distance=0.26713759910914037), word(word='SECURITY_DELAY', distance=0.27014133032799625), word(word='ELAPSED_TIME', distance=0.2742448962180103), word(word='LATE_AIRCRAFT_DELAY', distance=0.2805168760283915), word(word='WEATHER_DELAY', distance=0.29269570553710167), word(word='DESTINATION_AIRPORT', distance=0.45606976251904774), word(word='ORIGIN_AIRPORT', distance=0.4606195821065886)]
# [word(word='DAY_OF_WEEK', distance=0.10693239101189989), word(word='FLIGHT_NUMBER', distance=0.17546896289202973), word(word='ARRIVAL_DELAY', distance=0.17944464596796428), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18324936474507592), word(word='CANCELLATION_REASON', distance=0.18870550788286178), word(word='SCHEDULED_TIME', distance=0.19451025994495952), word(word='DEPARTURE_DELAY', distance=0.19670009076850392), word(word='ELAPSED_TIME', distance=0.19911909711678089), word(word='DATE', distance=0.20012988833981105), word(word='TAIL_NUMBER', distance=0.22534655955345784), word(word='AIR_SYSTEM_DELAY', distance=0.23656684370960845), word(word='SECURITY_DELAY', distance=0.2434192567492094), word(word='CANCELLED', distance=0.2437595422430492), word(word='LATE_AIRCRAFT_DELAY', distance=0.24422946378449206), word(word='AIRLINE_DELAY', distance=0.25548467010510023), word(word='WEATHER_DELAY', distance=0.28639673741061833), word(word='AIRLINE', distance=0.418680566952891), word(word='ORIGIN_AIRPORT', distance=0.4775848836754625), word(word='DESTINATION_AIRPORT', distance=0.4965760920887633)]
# [word(word='DAY_OF_WEEK', distance=0.12340626310504166), word(word='FLIGHT_NUMBER', distance=0.12429270123598157), word(word='CANCELLATION_REASON', distance=0.15634241012457206), word(word='DATE', distance=0.16516599110115415), word(word='TAIL_NUMBER', distance=0.1810529634308733), word(word='CANCELLED', distance=0.18106016078106724), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.19250632542511292), word(word='AIR_SYSTEM_DELAY', distance=0.19379586757357992), word(word='AIRLINE_DELAY', distance=0.20419703798831024), word(word='SECURITY_DELAY', distance=0.21112418125425303), word(word='ARRIVAL_DELAY', distance=0.22153574039686852), word(word='SCHEDULED_TIME', distance=0.22390444297604073), word(word='LATE_AIRCRAFT_DELAY', distance=0.23315587282143868), word(word='ELAPSED_TIME', distance=0.23573823706639596), word(word='DEPARTURE_DELAY', distance=0.23813922582642932), word(word='WEATHER_DELAY', distance=0.2672927722517974), word(word='AIRLINE', distance=0.34872623647158585), word(word='ORIGIN_AIRPORT', distance=0.4171259628498819), word(word='DESTINATION_AIRPORT', distance=0.47309317111068117)]
# [word(word='DAY_OF_WEEK', distance=0.13233978617188125), word(word='ARRIVAL_DELAY', distance=0.1396539514924463), word(word='CANCELLATION_REASON', distance=0.1620241528847579), word(word='DEPARTURE_DELAY', distance=0.1781371077233589), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18677895008549994), word(word='DATE', distance=0.1874230802386705), word(word='FLIGHT_NUMBER', distance=0.20009455278151744), word(word='SCHEDULED_TIME', distance=0.20095715737012954), word(word='AIRLINE_DELAY', distance=0.20123170473098406), word(word='AIR_SYSTEM_DELAY', distance=0.21447562425871614), word(word='CANCELLED', distance=0.21621754874545485), word(word='ELAPSED_TIME', distance=0.2180856591290974), word(word='SECURITY_DELAY', distance=0.23251743233116562), word(word='LATE_AIRCRAFT_DELAY', distance=0.2335143997257293), word(word='WEATHER_DELAY', distance=0.25459573920344913), word(word='TAIL_NUMBER', distance=0.25924228057867604), word(word='AIRLINE', distance=0.34712270743309237), word(word='ORIGIN_AIRPORT', distance=0.4359467160411816), word(word='DESTINATION_AIRPORT', distance=0.44776444324849596)]
# [word(word='DAY_OF_WEEK', distance=0.10906468209609399), word(word='AIR_SYSTEM_DELAY', distance=0.14336527919744257), word(word='ARRIVAL_DELAY', distance=0.15974535828592495), word(word='FLIGHT_NUMBER', distance=0.16586047731540143), word(word='CANCELLATION_REASON', distance=0.16825975962192696), word(word='SECURITY_DELAY', distance=0.17067335117030602), word(word='DEPARTURE_DELAY', distance=0.17113994129445642), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.1776671394157111), word(word='DATE', distance=0.17967832614905732), word(word='AIRLINE_DELAY', distance=0.17983921827451055), word(word='LATE_AIRCRAFT_DELAY', distance=0.18057063259545292), word(word='TAIL_NUMBER', distance=0.20030455134892955), word(word='SCHEDULED_TIME', distance=0.20092896548878825), word(word='CANCELLED', distance=0.21312762871202728), word(word='WEATHER_DELAY', distance=0.22215543307546193), word(word='ELAPSED_TIME', distance=0.2324831169954562), word(word='AIRLINE', distance=0.3829089421498314), word(word='ORIGIN_AIRPORT', distance=0.46431694681755964), word(word='DESTINATION_AIRPORT', distance=0.49270003651845695)]
# [word(word='DAY_OF_WEEK', distance=0.10525884556141119), word(word='FLIGHT_NUMBER', distance=0.14810499204232985), word(word='CANCELLATION_REASON', distance=0.17243695468364528), word(word='TAIL_NUMBER', distance=0.17289857495945404), word(word='AIR_SYSTEM_DELAY', distance=0.1823163056933106), word(word='DATE', distance=0.18488569204676653), word(word='ARRIVAL_DELAY', distance=0.18906078634493517), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.19282972984104796), word(word='CANCELLED', distance=0.19942773004396508), word(word='SCHEDULED_TIME', distance=0.2029042341982107), word(word='ELAPSED_TIME', distance=0.20892833837529146), word(word='AIRLINE_DELAY', distance=0.21759774680823452), word(word='SECURITY_DELAY', distance=0.2213349519579949), word(word='DEPARTURE_DELAY', distance=0.22421370925401463), word(word='LATE_AIRCRAFT_DELAY', distance=0.23174366899771248), word(word='WEATHER_DELAY', distance=0.23736008090901473), word(word='AIRLINE', distance=0.3661076472837139), word(word='ORIGIN_AIRPORT', distance=0.4175082785321985), word(word='DESTINATION_AIRPORT', distance=0.4431663466275194)]
# [word(word='DAY_OF_WEEK', distance=0.10318903267230928), word(word='ARRIVAL_DELAY', distance=0.14216671721003993), word(word='DEPARTURE_DELAY', distance=0.15804986131129883), word(word='CANCELLATION_REASON', distance=0.16560544492161078), word(word='FLIGHT_NUMBER', distance=0.1866100219766561), word(word='DATE', distance=0.18707771346249746), word(word='AIR_SYSTEM_DELAY', distance=0.18760523374458793), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18775990621458893), word(word='SCHEDULED_TIME', distance=0.19001300182250935), word(word='SECURITY_DELAY', distance=0.202888664484711), word(word='LATE_AIRCRAFT_DELAY', distance=0.2029441615112254), word(word='ELAPSED_TIME', distance=0.20508677547649068), word(word='AIRLINE_DELAY', distance=0.20981099436670703), word(word='WEATHER_DELAY', distance=0.21623937048663167), word(word='CANCELLED', distance=0.22044295362758604), word(word='TAIL_NUMBER', distance=0.23264941698934583), word(word='AIRLINE', distance=0.40221297321518423), word(word='ORIGIN_AIRPORT', distance=0.4693891820348206), word(word='DESTINATION_AIRPORT', distance=0.47702862900308785)]
# [word(word='DAY_OF_WEEK', distance=0.11131576092939643), word(word='ARRIVAL_DELAY', distance=0.1554458559018802), word(word='DEPARTURE_DELAY', distance=0.1664436370611968), word(word='FLIGHT_NUMBER', distance=0.1720328905904328), word(word='CANCELLATION_REASON', distance=0.17333132021338093), word(word='SECURITY_DELAY', distance=0.1813718726661664), word(word='DATE', distance=0.18510879640974554), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18739168679219065), word(word='AIR_SYSTEM_DELAY', distance=0.1929997213311906), word(word='SCHEDULED_TIME', distance=0.20267275896740067), word(word='ELAPSED_TIME', distance=0.20640118908782745), word(word='AIRLINE_DELAY', distance=0.21246130437897393), word(word='TAIL_NUMBER', distance=0.21436005103551037), word(word='CANCELLED', distance=0.2151709715142901), word(word='LATE_AIRCRAFT_DELAY', distance=0.21892423583934584), word(word='WEATHER_DELAY', distance=0.25007618087947603), word(word='AIRLINE', distance=0.38989165935812287), word(word='ORIGIN_AIRPORT', distance=0.4486674950854094), word(word='DESTINATION_AIRPORT', distance=0.47139819137965333)]
# [word(word='DAY_OF_WEEK', distance=0.09717169114439661), word(word='FLIGHT_NUMBER', distance=0.1632570776287956), word(word='ARRIVAL_DELAY', distance=0.18169370743099267), word(word='LATE_AIRCRAFT_DELAY', distance=0.18170677048662598), word(word='AIR_SYSTEM_DELAY', distance=0.18505218413175917), word(word='TAIL_NUMBER', distance=0.18678697110969678), word(word='CANCELLATION_REASON', distance=0.18733474161522723), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18955186187740136), word(word='SECURITY_DELAY', distance=0.19869411548379634), word(word='SCHEDULED_TIME', distance=0.20171642173431226), word(word='DATE', distance=0.20362031247975854), word(word='AIRLINE_DELAY', distance=0.20562175322328102), word(word='DEPARTURE_DELAY', distance=0.21015447307045532), word(word='ELAPSED_TIME', distance=0.21370194315905555), word(word='WEATHER_DELAY', distance=0.2357164024266959), word(word='CANCELLED', distance=0.23745493320391264), word(word='AIRLINE', distance=0.40073852227856244), word(word='ORIGIN_AIRPORT', distance=0.4657593230223749), word(word='DESTINATION_AIRPORT', distance=0.49702363665881755)]
# [word(word='FLIGHT_NUMBER', distance=0.0999240659596623), word(word='TAIL_NUMBER', distance=0.14673569112748952), word(word='DAY_OF_WEEK', distance=0.14871221577648197), word(word='CANCELLATION_REASON', distance=0.17175742181232434), word(word='DATE', distance=0.1880516659345315), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.19375459787337246), word(word='CANCELLED', distance=0.1962575594359378), word(word='SCHEDULED_TIME', distance=0.21257968268825922), word(word='ELAPSED_TIME', distance=0.2226594734448213), word(word='ARRIVAL_DELAY', distance=0.23650132585050854), word(word='AIR_SYSTEM_DELAY', distance=0.24479937582945066), word(word='SECURITY_DELAY', distance=0.257973789622984), word(word='DEPARTURE_DELAY', distance=0.26326342976760453), word(word='AIRLINE_DELAY', distance=0.265907103911162), word(word='LATE_AIRCRAFT_DELAY', distance=0.2735229736244458), word(word='WEATHER_DELAY', distance=0.306825285016189), word(word='ORIGIN_AIRPORT', distance=0.42683478074460923), word(word='AIRLINE', distance=0.42907417396052305), word(word='DESTINATION_AIRPORT', distance=0.44429343037588775)]
# [word(word='DAY_OF_WEEK', distance=0.13706072360245358), word(word='ARRIVAL_DELAY', distance=0.14082755120494972), word(word='DEPARTURE_DELAY', distance=0.15340683433199342), word(word='CANCELLATION_REASON', distance=0.16827753155407976), word(word='FLIGHT_NUMBER', distance=0.17109035549957408), word(word='SECURITY_DELAY', distance=0.18360743256962853), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18557850463852832), word(word='DATE', distance=0.19024306437687044), word(word='SCHEDULED_TIME', distance=0.20394897359018826), word(word='AIR_SYSTEM_DELAY', distance=0.21245796602184408), word(word='TAIL_NUMBER', distance=0.21339457838265075), word(word='ELAPSED_TIME', distance=0.22169744213133424), word(word='LATE_AIRCRAFT_DELAY', distance=0.22317262896357826), word(word='CANCELLED', distance=0.22588410657593627), word(word='AIRLINE_DELAY', distance=0.2379933053571358), word(word='WEATHER_DELAY', distance=0.2626827311212462), word(word='ORIGIN_AIRPORT', distance=0.4158048469208331), word(word='AIRLINE', distance=0.4501646062002679), word(word='DESTINATION_AIRPORT', distance=0.46910070174198104)]
# [word(word='DAY_OF_WEEK', distance=0.13919986888456892), word(word='ARRIVAL_DELAY', distance=0.1438858857060158), word(word='DEPARTURE_DELAY', distance=0.15920590767161458), word(word='CANCELLATION_REASON', distance=0.17322264044552826), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18625983881968777), word(word='FLIGHT_NUMBER', distance=0.18795729343251566), word(word='SECURITY_DELAY', distance=0.1902050489245657), word(word='DATE', distance=0.1990784837482905), word(word='SCHEDULED_TIME', distance=0.20245024154559055), word(word='ELAPSED_TIME', distance=0.215195753514842), word(word='AIR_SYSTEM_DELAY', distance=0.21547087908977192), word(word='LATE_AIRCRAFT_DELAY', distance=0.2233248804295952), word(word='TAIL_NUMBER', distance=0.23458418298562356), word(word='CANCELLED', distance=0.2355634468530875), word(word='AIRLINE_DELAY', distance=0.24135529466725592), word(word='WEATHER_DELAY', distance=0.2569493266476468), word(word='ORIGIN_AIRPORT', distance=0.42196627521980035), word(word='AIRLINE', distance=0.4525248609096365), word(word='DESTINATION_AIRPORT', distance=0.4725398819281106)]
# [word(word='CANCELLATION_REASON', distance=0.13467136647171918), word(word='FLIGHT_NUMBER', distance=0.15419347640617664), word(word='AIR_SYSTEM_DELAY', distance=0.1661160905759873), word(word='DAY_OF_WEEK', distance=0.16753665779062932), word(word='CANCELLED', distance=0.18192399297138695), word(word='ARRIVAL_DELAY', distance=0.186264422978481), word(word='DATE', distance=0.19316662751109648), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.19349336375844528), word(word='TAIL_NUMBER', distance=0.2020348064667239), word(word='AIRLINE_DELAY', distance=0.20628650411002358), word(word='DEPARTURE_DELAY', distance=0.21485586542748347), word(word='SCHEDULED_TIME', distance=0.2209852215855962), word(word='SECURITY_DELAY', distance=0.23740732315808855), word(word='ELAPSED_TIME', distance=0.2571439253146296), word(word='LATE_AIRCRAFT_DELAY', distance=0.26240207807206795), word(word='WEATHER_DELAY', distance=0.2706970887291885), word(word='AIRLINE', distance=0.3376045270289413), word(word='ORIGIN_AIRPORT', distance=0.35660440460258613), word(word='DESTINATION_AIRPORT', distance=0.3889169963347334)]
# [word(word='CANCELLATION_REASON', distance=0.16010386939265298), word(word='ARRIVAL_DELAY', distance=0.16076273720408352), word(word='FLIGHT_NUMBER', distance=0.16178111410021223), word(word='DAY_OF_WEEK', distance=0.16276671527099518), word(word='TAIL_NUMBER', distance=0.172438350165375), word(word='DEPARTURE_DELAY', distance=0.19010952659592228), word(word='AIR_SYSTEM_DELAY', distance=0.19523896553112607), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.19666487929777232), word(word='DATE', distance=0.2040158720072659), word(word='SCHEDULED_TIME', distance=0.21537292193262758), word(word='SECURITY_DELAY', distance=0.21893848147170214), word(word='ELAPSED_TIME', distance=0.2220432026716075), word(word='WEATHER_DELAY', distance=0.22518171960557054), word(word='CANCELLED', distance=0.22686615473366079), word(word='AIRLINE_DELAY', distance=0.22700761159286031), word(word='LATE_AIRCRAFT_DELAY', distance=0.2294916718329174), word(word='ORIGIN_AIRPORT', distance=0.4150990788625274), word(word='AIRLINE', distance=0.42768345161171606), word(word='DESTINATION_AIRPORT', distance=0.45895114612996935)]
# [word(word='DAY_OF_WEEK', distance=0.12184795761892508), word(word='ARRIVAL_DELAY', distance=0.14569884673767386), word(word='DEPARTURE_DELAY', distance=0.16261691054872007), word(word='AIR_SYSTEM_DELAY', distance=0.16332276057045747), word(word='FLIGHT_NUMBER', distance=0.16454080503626023), word(word='CANCELLATION_REASON', distance=0.16750360132180897), word(word='SECURITY_DELAY', distance=0.1696398821251961), word(word='LATE_AIRCRAFT_DELAY', distance=0.17023917886842344), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.17817641888022262), word(word='TAIL_NUMBER', distance=0.18436764085588897), word(word='DATE', distance=0.18519025176349635), word(word='AIRLINE_DELAY', distance=0.18548138017507054), word(word='SCHEDULED_TIME', distance=0.1947031326018035), word(word='WEATHER_DELAY', distance=0.20607981994863145), word(word='ELAPSED_TIME', distance=0.20755292088423583), word(word='CANCELLED', distance=0.22263983369291096), word(word='ORIGIN_AIRPORT', distance=0.4192740076452356), word(word='AIRLINE', distance=0.42110091366468505), word(word='DESTINATION_AIRPORT', distance=0.47189425002011587)]
# [word(word='DAY_OF_WEEK', distance=0.13803363088402665), word(word='ARRIVAL_DELAY', distance=0.14431378746426338), word(word='CANCELLATION_REASON', distance=0.14804921772580193), word(word='DATE', distance=0.149679831603178), word(word='SCHEDULED_TIME', distance=0.15807385736398216), word(word='FLIGHT_NUMBER', distance=0.1627220943839791), word(word='DEPARTURE_DELAY', distance=0.17031339886748953), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.17158271122406), word(word='TAIL_NUMBER', distance=0.19335120233914938), word(word='CANCELLED', distance=0.19605956688032344), word(word='ELAPSED_TIME', distance=0.20577291286099775), word(word='AIR_SYSTEM_DELAY', distance=0.20888195813361665), word(word='SECURITY_DELAY', distance=0.22518370265487542), word(word='LATE_AIRCRAFT_DELAY', distance=0.22804229059385783), word(word='AIRLINE_DELAY', distance=0.23778148444813485), word(word='WEATHER_DELAY', distance=0.26470940266317333), word(word='ORIGIN_AIRPORT', distance=0.35519991919078153), word(word='DESTINATION_AIRPORT', distance=0.39966090870101956), word(word='AIRLINE', distance=0.4203030876854683)]
# [word(word='DAY_OF_WEEK', distance=0.12772264684216916), word(word='FLIGHT_NUMBER', distance=0.18999035515100526), word(word='ARRIVAL_DELAY', distance=0.1912165277888832), word(word='CANCELLATION_REASON', distance=0.21414522792041168), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.21869058992094859), word(word='SCHEDULED_TIME', distance=0.2190596467955328), word(word='DEPARTURE_DELAY', distance=0.2213401401417633), word(word='ELAPSED_TIME', distance=0.23048869162860963), word(word='SECURITY_DELAY', distance=0.23293944582009518), word(word='TAIL_NUMBER', distance=0.23442484197222369), word(word='DATE', distance=0.23671029174252756), word(word='LATE_AIRCRAFT_DELAY', distance=0.25659108616546433), word(word='AIR_SYSTEM_DELAY', distance=0.25712317677354735), word(word='CANCELLED', distance=0.2704026474041099), word(word='AIRLINE_DELAY', distance=0.2901531088545046), word(word='WEATHER_DELAY', distance=0.3058316426377796), word(word='ORIGIN_AIRPORT', distance=0.45493508632109325), word(word='AIRLINE', distance=0.47603832385605693), word(word='DESTINATION_AIRPORT', distance=0.5048515025644806)]
# [word(word='CANCELLATION_REASON', distance=0.14486487669695325), word(word='DATE', distance=0.14505221390302758), word(word='ARRIVAL_DELAY', distance=0.14765458359371753), word(word='FLIGHT_NUMBER', distance=0.15079539357058047), word(word='DEPARTURE_DELAY', distance=0.15923454599614584), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.1662388286786053), word(word='DAY_OF_WEEK', distance=0.17232669466231554), word(word='SCHEDULED_TIME', distance=0.17691409190821994), word(word='CANCELLED', distance=0.18203638124118604), word(word='TAIL_NUMBER', distance=0.20115508767197887), word(word='AIR_SYSTEM_DELAY', distance=0.20856629386473957), word(word='AIRLINE_DELAY', distance=0.21704337446703037), word(word='ELAPSED_TIME', distance=0.21718884196860633), word(word='SECURITY_DELAY', distance=0.22260483171552703), word(word='LATE_AIRCRAFT_DELAY', distance=0.24283525889645008), word(word='WEATHER_DELAY', distance=0.2699947989101964), word(word='ORIGIN_AIRPORT', distance=0.326460617084655), word(word='DESTINATION_AIRPORT', distance=0.3692959652835567), word(word='AIRLINE', distance=0.40298079237960904)]
# [word(word='DAY_OF_WEEK', distance=0.11749436834435767), word(word='ARRIVAL_DELAY', distance=0.1811406015432825), word(word='FLIGHT_NUMBER', distance=0.18149086706097473), word(word='LATE_AIRCRAFT_DELAY', distance=0.196130709910038), word(word='AIR_SYSTEM_DELAY', distance=0.19811342972168888), word(word='CANCELLATION_REASON', distance=0.2000663170867596), word(word='SECURITY_DELAY', distance=0.2012496773856679), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.2096068708763945), word(word='DEPARTURE_DELAY', distance=0.2126522100074244), word(word='SCHEDULED_TIME', distance=0.21336429639340793), word(word='ELAPSED_TIME', distance=0.21602732175600903), word(word='WEATHER_DELAY', distance=0.21914946138798141), word(word='TAIL_NUMBER', distance=0.21985727297730961), word(word='DATE', distance=0.22478322800874628), word(word='AIRLINE_DELAY', distance=0.2305110508584295), word(word='CANCELLED', distance=0.25527225426368394), word(word='ORIGIN_AIRPORT', distance=0.4503924139994071), word(word='AIRLINE', distance=0.4618432298499694), word(word='DESTINATION_AIRPORT', distance=0.5071871930130231)]
# [word(word='ARRIVAL_DELAY', distance=0.13361941279678258), word(word='DAY_OF_WEEK', distance=0.14026013185576736), word(word='DEPARTURE_DELAY', distance=0.16293045482184332), word(word='CANCELLATION_REASON', distance=0.16742781095368986), word(word='FLIGHT_NUMBER', distance=0.172179402305926), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18509115647101126), word(word='SECURITY_DELAY', distance=0.19614272607074923), word(word='SCHEDULED_TIME', distance=0.1970999380571391), word(word='DATE', distance=0.19801991280375286), word(word='TAIL_NUMBER', distance=0.2176772342744927), word(word='ELAPSED_TIME', distance=0.2220841695042589), word(word='AIR_SYSTEM_DELAY', distance=0.22402061417703256), word(word='CANCELLED', distance=0.22778324480317425), word(word='LATE_AIRCRAFT_DELAY', distance=0.2376236746261846), word(word='AIRLINE_DELAY', distance=0.2470819689657292), word(word='WEATHER_DELAY', distance=0.26838177986667056), word(word='DESTINATION_AIRPORT', distance=0.4121308698355599), word(word='ORIGIN_AIRPORT', distance=0.4277903687533342), word(word='AIRLINE', distance=0.44714732256210643)]
# [word(word='ARRIVAL_DELAY', distance=0.13726452064124295), word(word='DAY_OF_WEEK', distance=0.15129903595783234), word(word='CANCELLATION_REASON', distance=0.16789783672182867), word(word='DEPARTURE_DELAY', distance=0.1740863488413139), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.18550432560750763), word(word='SCHEDULED_TIME', distance=0.19597239890520102), word(word='FLIGHT_NUMBER', distance=0.1962459478261266), word(word='DATE', distance=0.20915532927905378), word(word='ELAPSED_TIME', distance=0.21384078427874886), word(word='AIR_SYSTEM_DELAY', distance=0.22210595889899443), word(word='WEATHER_DELAY', distance=0.22642206816288546), word(word='SECURITY_DELAY', distance=0.228794182007256), word(word='LATE_AIRCRAFT_DELAY', distance=0.23256333514857297), word(word='CANCELLED', distance=0.24133477672995385), word(word='AIRLINE_DELAY', distance=0.2449289472647529), word(word='TAIL_NUMBER', distance=0.24556389099472697), word(word='DESTINATION_AIRPORT', distance=0.41890285258185733), word(word='ORIGIN_AIRPORT', distance=0.4453784447827003), word(word='AIRLINE', distance=0.45294256242174147)]
# [word(word='CANCELLATION_REASON', distance=0.1340751789476189), word(word='FLIGHT_NUMBER', distance=0.16163183144341742), word(word='DAY_OF_WEEK', distance=0.17937222678316356), word(word='AIR_SYSTEM_DELAY', distance=0.18192592544831387), word(word='CANCELLED', distance=0.18618846551205115), word(word='ARRIVAL_DELAY', distance=0.18883025156013755), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.19011452027504638), word(word='DATE', distance=0.19831630859967186), word(word='TAIL_NUMBER', distance=0.2124658427419578), word(word='DEPARTURE_DELAY', distance=0.2146247336284205), word(word='AIRLINE_DELAY', distance=0.21468780905046447), word(word='SCHEDULED_TIME', distance=0.21835766800988343), word(word='SECURITY_DELAY', distance=0.25190331480318695), word(word='ELAPSED_TIME', distance=0.26190860863775745), word(word='LATE_AIRCRAFT_DELAY', distance=0.28047777506102634), word(word='WEATHER_DELAY', distance=0.2813814304057347), word(word='AIRLINE', distance=0.3305545882674614), word(word='DESTINATION_AIRPORT', distance=0.33935960535796617), word(word='ORIGIN_AIRPORT', distance=0.38815140601891784)]
# [word(word='CANCELLATION_REASON', distance=0.1561664134285089), word(word='ARRIVAL_DELAY', distance=0.16038792883364306), word(word='FLIGHT_NUMBER', distance=0.16543230881760151), word(word='DAY_OF_WEEK', distance=0.1706053365792265), word(word='TAIL_NUMBER', distance=0.17935332584258246), word(word='DEPARTURE_DELAY', distance=0.18727356654487803), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.1906076005135129), word(word='DATE', distance=0.20568484507160512), word(word='AIR_SYSTEM_DELAY', distance=0.20638603630918728), word(word='SCHEDULED_TIME', distance=0.21018614510038136), word(word='ELAPSED_TIME', distance=0.22402856797797255), word(word='CANCELLED', distance=0.22736142285511296), word(word='SECURITY_DELAY', distance=0.22959461478401666), word(word='AIRLINE_DELAY', distance=0.2316047357913067), word(word='WEATHER_DELAY', distance=0.23272929242268137), word(word='LATE_AIRCRAFT_DELAY', distance=0.24364971842005334), word(word='DESTINATION_AIRPORT', distance=0.41073670666740136), word(word='AIRLINE', distance=0.41796960975187836), word(word='ORIGIN_AIRPORT', distance=0.441054678799505)]
# [word(word='DAY_OF_WEEK', distance=0.124155578502814), word(word='ARRIVAL_DELAY', distance=0.13950399623444643), word(word='FLIGHT_NUMBER', distance=0.16510394213901936), word(word='CANCELLATION_REASON', distance=0.16646586922779927), word(word='DEPARTURE_DELAY', distance=0.16982086628037973), word(word='AIR_SYSTEM_DELAY', distance=0.1726320091466319), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.17748736710925894), word(word='SECURITY_DELAY', distance=0.17944981524647852), word(word='LATE_AIRCRAFT_DELAY', distance=0.1818997317216453), word(word='TAIL_NUMBER', distance=0.18768269190294062), word(word='SCHEDULED_TIME', distance=0.18893118191175706), word(word='DATE', distance=0.1911169343879482), word(word='AIRLINE_DELAY', distance=0.19284216190501635), word(word='ELAPSED_TIME', distance=0.20763221619202132), word(word='WEATHER_DELAY', distance=0.2107624525382823), word(word='CANCELLED', distance=0.2238517380519458), word(word='AIRLINE', distance=0.41866143149879376), word(word='DESTINATION_AIRPORT', distance=0.42592697564369053), word(word='ORIGIN_AIRPORT', distance=0.42861126209452316)]
# [word(word='CANCELLATION_REASON', distance=0.1453063483407936), word(word='ARRIVAL_DELAY', distance=0.14547544119409783), word(word='DAY_OF_WEEK', distance=0.14817414207600776), word(word='DATE', distance=0.1534316924281668), word(word='SCHEDULED_TIME', distance=0.15442718147724077), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.16664213439093933), word(word='FLIGHT_NUMBER', distance=0.16802991757023067), word(word='DEPARTURE_DELAY', distance=0.1688048901229544), word(word='CANCELLED', distance=0.19822492563570104), word(word='TAIL_NUMBER', distance=0.20193433172404374), word(word='ELAPSED_TIME', distance=0.20938506435211568), word(word='AIR_SYSTEM_DELAY', distance=0.22209168092260567), word(word='SECURITY_DELAY', distance=0.23791162682906963), word(word='AIRLINE_DELAY', distance=0.24388895411879863), word(word='LATE_AIRCRAFT_DELAY', distance=0.24463210581655226), word(word='WEATHER_DELAY', distance=0.2736692939678552), word(word='DESTINATION_AIRPORT', distance=0.3491010071244325), word(word='ORIGIN_AIRPORT', distance=0.38494141389394787), word(word='AIRLINE', distance=0.4108196113407734)]
# [word(word='DAY_OF_WEEK', distance=0.1331690349163036), word(word='ARRIVAL_DELAY', distance=0.18886636028158854), word(word='FLIGHT_NUMBER', distance=0.19127249630949839), word(word='CANCELLATION_REASON', distance=0.20844428649101532), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.21136818434842086), word(word='SCHEDULED_TIME', distance=0.21267598073412153), word(word='DEPARTURE_DELAY', distance=0.21683827333118788), word(word='ELAPSED_TIME', distance=0.2305307968293655), word(word='DATE', distance=0.23627530280657327), word(word='TAIL_NUMBER', distance=0.2384471099617338), word(word='SECURITY_DELAY', distance=0.2407270214226549), word(word='AIR_SYSTEM_DELAY', distance=0.26499650668778285), word(word='LATE_AIRCRAFT_DELAY', distance=0.26746361916488015), word(word='CANCELLED', distance=0.268894305676297), word(word='AIRLINE_DELAY', distance=0.29220466356951924), word(word='WEATHER_DELAY', distance=0.31041806793290405), word(word='DESTINATION_AIRPORT', distance=0.46008408237031295), word(word='AIRLINE', distance=0.4657659240966754), word(word='ORIGIN_AIRPORT', distance=0.47672510909293964)]
# [word(word='ARRIVAL_DELAY', distance=0.1454274567988062), word(word='CANCELLATION_REASON', distance=0.15245316623042693), word(word='FLIGHT_NUMBER', distance=0.16112767086725632), word(word='DATE', distance=0.16563460395315555), word(word='SCHEDULED_DEPARTURE_HOUR', distance=0.17408738661506262), word(word='SCHEDULED_TIME', distance=0.17542222196520862), word(word='DEPARTURE_DELAY', distance=0.181492138373903), word(word='DAY_OF_WEEK', distance=0.18472860781017908), word(word='CANCELLED', distance=0.19359523292453495), word(word='TAIL_NUMBER', distance=0.21556129635316246), word(word='ELAPSED_TIME', distance=0.22559754950667343), word(word='AIR_SYSTEM_DELAY', distance=0.23347303424669963), word(word='AIRLINE_DELAY', distance=0.2384817125247496), word(word='SECURITY_DELAY', distance=0.24817033214518214), word(word='LATE_AIRCRAFT_DELAY', distance=0.27129924063247646), word(word='WEATHER_DELAY', distance=0.28551090594851725), word(word='DESTINATION_AIRPORT', distance=0.2933185284547001), word(word='ORIGIN_AIRPORT', distance=0.3520750904247142), word(word='AIRLINE', distance=0.40517051040313223)]
